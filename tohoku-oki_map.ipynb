# %%
# Imports
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import xarray as xr

import cartopy.crs as ccrs
import cartopy.feature as creature
from cartopy.io.img_tiles import OSM

# %%
# Plot Map

# Set projection type
proj = ccrs.PlateCarree()

# Make figure
plt.figure(figsize=(10, 6))
ax = plt.axes(projection=proj)

# Add OSM tiles
tiles = OSM()
ax.add_image(tiles, 7)  # Adjust zoom level as needed

ax.set_title('Tohoku-oki Earthquake Locations', fontsize=14, pad=15)  # Increase title font size

# Set extent boundaries
extent = [134, 145, 32, 40]
ax.set_extent(extent)

# Load Natural Earth 10m coastline data
ax.add_feature(cfeature.COASTLINE.with_scale('10m'))

# Make latitude and longitude gridlines with higher resolution
grid = ax.gridlines(draw_labels=True, linewidth=1, color='gray', alpha=0.8, linestyle='--', crs=ccrs.PlateCarree())
grid.xlabels_top = False
grid.ylabels_right = False

# Add important points with adjusted marker sizes
ax.scatter(137.31, 36.43, color='yellow', marker='o', s=200, label="Kamioka Observatory", edgecolor='k') 
ax.scatter(142.68, 38.19, color='red', marker='*', s=220, label="Tohoku-oki Epicenter", edgecolor='k') 

# Add legend
ax.legend()

# Manually add a scale bar
ax.plot([135, 136], [39, 39], color='black', transform=proj)        # Horizontal line
ax.plot([135, 135], [38.95, 39.05], color='black', transform=proj)  # Left vertical line
ax.plot([136, 136], [38.95, 39.05], color='black', transform=proj)  # Right vertical line
ax.text(135.2, 38.8, "100 km", fontsize=8)  

plt.show()
# Out:
# C:\Users\bianc\anaconda3\envs\GPGN268\Lib\site-packages\cartopy\mpl\gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# C:\Users\bianc\anaconda3\envs\GPGN268\Lib\site-packages\cartopy\mpl\gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
