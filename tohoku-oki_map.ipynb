# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import xarray as xr

import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# # Kamioka Station
# N Latitude  (deg)    :   36.42530   0.00010
#
# E Longitude (deg)    :  137.30840   0.00010
#
# # epicentre coordinates
# 38.19° N, 142.68° E

# %%
# Plot Map

# Set projection type
proj = ccrs.PlateCarree()

# Make figure
plt.figure()
ax = plt.axes(projection=proj)
ax.stock_img()
ax.coastlines(resolution="50m")
ax.set_title('Tohoki-oki Earthquake Locations', fontsize=10, pad=15)

# Set extent boundaries
extent = [134, 145, 32, 40]
ax.set_extent(extent)


# Add topography
#x = 
#y =
#z =

# Add contour
#contour = ax.contourf(x, y, z, cmap='terrain', alpha=0.5, transform=proj)
#plt.colorbar(contour, ax=ax, label='Height (m)', orientation='vertical', pad=.1, shrink=0.7, location='left')

# Make latitude and longitude gridlines
grid = ax.gridlines(draw_labels=True, linewidth=1, color='gray', alpha=0.8, linestyle='--')
grid.left_labels = False
grid.bottom_labels = False

# Add important points
ax.scatter(137.31, 36.43, color='red', marker='o', s=220, label="Kamioka Observatory")
ax.scatter(137.31, 36.43, color='black', marker='o', s=220, facecolors='none')

ax.scatter(142.68, 38.19, color='yellow', marker='*', s=250, label = "Tohoku-oki Epicenter")
ax.scatter(142.68, 38.19, color='black', marker='*', s=250, facecolors='none')
